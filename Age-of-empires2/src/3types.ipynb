# %%
import pandas as pd

# %%
dfA = pd.read_csv('AoEData.csv')
dfh = pd.read_csv('hidden.csv')
dfs = pd.read_csv('s-tier.csv')

# %%
ids = dfs['tournament_id']
idh = dfh['tournament_id']
ida = dfA['tournament_id']

# %%
len(ids)
# Out:
# 2426

# %%
len(idh)
# Out:
# 126

# %%
dfA
# Out:
#                       name     id  tournament_id        date  prizemoney  \
# 0      Arabia Invitational      1             15  2016-02-01      3000.0
# 1      Arabia Invitational      2             15  2016-02-01      3000.0
# 2      Arabia Invitational      3             15  2016-02-01      3000.0
# 3      Arabia Invitational      4             15  2016-02-08      3000.0
# 4      Arabia Invitational      5             15  2016-02-08      3000.0
# ...                    ...    ...            ...         ...         ...
# 13289             NAC CORP  13313            673  2024-02-02         NaN
# 13290          Swidden Cup  13447            685  2024-02-04         NaN
# 13291          Swidden Cup  13448            685  2024-02-04         NaN
# 13292        India 1v1 Cup  13500            686  2024-03-09         NaN
# 13293        India 1v1 Cup  13501            686  2024-03-09         NaN
#
#                      Knockout_stage  Knockout_stage_importance  player_1_id  \
# ...

# %%
listaS = set(ids)
idh.drop_duplicates(inplace=True)
ida.drop_duplicates(inplace=True)

# %%
# Out:
# 57

# %%
aux = dfA[~dfA['tournament_id'].isin(listaS)]

# %%
dfNormal = aux[~aux['tournament_id'].isin(idh)]
dfNormal
# Out:
#                       name     id  tournament_id        date  prizemoney  \
# 0      Arabia Invitational      1             15  2016-02-01      3000.0
# 1      Arabia Invitational      2             15  2016-02-01      3000.0
# 2      Arabia Invitational      3             15  2016-02-01      3000.0
# 3      Arabia Invitational      4             15  2016-02-08      3000.0
# 4      Arabia Invitational      5             15  2016-02-08      3000.0
# ...                    ...    ...            ...         ...         ...
# 13289             NAC CORP  13313            673  2024-02-02         NaN
# 13290          Swidden Cup  13447            685  2024-02-04         NaN
# 13291          Swidden Cup  13448            685  2024-02-04         NaN
# 13292        India 1v1 Cup  13500            686  2024-03-09         NaN
# 13293        India 1v1 Cup  13501            686  2024-03-09         NaN
#
#                      Knockout_stage  Knockout_stage_importance  player_1_id  \
# ...

# %%
dfNormal.to_csv('normal.csv')

# %%
# Out:
#                       name     id  tournament_id        date  prizemoney  \
# 0      Arabia Invitational      1             15  2016-02-01      3000.0
# 1      Arabia Invitational      2             15  2016-02-01      3000.0
# 2      Arabia Invitational      3             15  2016-02-01      3000.0
# 3      Arabia Invitational      4             15  2016-02-08      3000.0
# 4      Arabia Invitational      5             15  2016-02-08      3000.0
# ...                    ...    ...            ...         ...         ...
# 13289             NAC CORP  13313            673  2024-02-02         NaN
# 13290          Swidden Cup  13447            685  2024-02-04         NaN
# 13291          Swidden Cup  13448            685  2024-02-04         NaN
# 13292        India 1v1 Cup  13500            686  2024-03-09         NaN
# 13293        India 1v1 Cup  13501            686  2024-03-09         NaN
#
#                      Knockout_stage  Knockout_stage_importance  player_1_id  \
# ...
